# %%
from generators import base_data_generator

# %%
from generators.products_generator import generate_products

products_path = generate_products(100)
products_path
# Out:
# Generated 500 products in /home/jovyan/work/data/products.json
# '/home/jovyan/work/data/products.json'

# %%
from generators.customers_generator import generate_customers

customers = generate_customers(100, "customers.json")
# Out:
# Generated 100 customers in: /home/jovyan/work/data/customers.json
#   brand_loyal: 10
#   browser: 7
#   budget: 30
#   premium: 12
#   regular: 41

# %%
from generators.transactions_generator import generate_transactions

historical_transactions = generate_transactions(45000, "historical_transactions.json")
# Out:
# Generated 45000 historical transactions in /home/jovyan/work/data/historical_transactions.json

# %%
from generators.association_rules_generator import generate_association_rules

association_rules_path = generate_association_rules(historical_transactions,"association_rules.json", min_support=0.15, min_confidence=0.60, min_conviction=2.00)
# Out:
# Generated 29 association rules in /home/jovyan/work/data/association_rules.json
# ['Conditioner', 'Shampoo'] => ['Hair Mask'] | support=0.223, confidence=0.895, lift=1.971
# ['Fitness Band', 'Running Shoes'] => ['Protein Shaker'] | support=0.207, confidence=0.872, lift=1.953
# ['Keyboard', 'Laptop'] => ['Wireless Mouse'] | support=0.222, confidence=0.865, lift=1.927
# ['Chocolate', 'Coffee Beans'] => ['Cookies'] | support=0.203, confidence=0.845, lift=1.921
# ['Laptop', 'Wireless Mouse'] => ['Keyboard'] | support=0.222, confidence=0.821, lift=1.873
# ['Hair Mask', 'Shampoo'] => ['Conditioner'] | support=0.223, confidence=0.811, lift=1.899
# ['Coffee Beans', 'Cookies'] => ['Chocolate'] | support=0.203, confidence=0.786, lift=1.873
# ['Protein Shaker', 'Running Shoes'] => ['Fitness Band'] | support=0.207, confidence=0.774, lift=1.859
# ['Shampoo'] => ['Hair Mask'] | support=0.275, confidence=0.768, lift=1.692
# ...
